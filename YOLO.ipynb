# %% [markdown]
# <a href="https://colab.research.google.com/github/willy1106101/YOLOV8/blob/main/YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# 主程式 TRAINS

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

# %% [markdown]
# PREDICT DETECT

# %%
from ultralytics import YOLO

# 載入模型（預訓練 or 自己訓練的）
model = YOLO("best.pt")
# model = YOLO("yolo11n.pt")

results = model.predict(
    source="images.jpg",
    imgsz=640,
    conf=0.25,
    save=True
)

# 讀取結果
for r in results:
    print(r.boxes.xyxy)   # bounding boxes
    print(r.boxes.cls)    # class id
    print(r.boxes.conf)   # confidence
